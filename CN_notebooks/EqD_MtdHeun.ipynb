# %%
import numpy as np

def df(x, y):
  return 
  
def heun(a, b, h, y0):
  x = np.arange(a, b+0.1, h)
  print(x)
  y = np.zeros((1, len(x)))
  
  y[0][0] = y0

  for i in range(0, len(x)-1):
    k1 = df(x[i], y[0][i])
    k2 = df(x[i]+h, y[0][i] + k1*h)
    k = (k1+k2)/2

    y[0][i+1] = y[0][i] + k*h

  print(y)
  


heun(0., 0.6, 0.2, 0.6)
# Out:
# [0.  0.2 0.4 0.6]
# [[0.6        0.382368   0.24690572 0.16379528]]
